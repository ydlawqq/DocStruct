# %%
from datasets import load_dataset
from sklearn.model_selection import train_test_split

ds = load_dataset("mychen76/ds_receipts_v2_test")


ds = ds['train'].to_pandas()

# %%
type(ds['text'][0])
# Out:
# str

# %%
import json

# %%
json.loads(json.loads(ds['text'][0]))
# Out:
# {'store_name': 'CHOEUN KOREANRESTAURANT',
#  'store_addr': '2621ORANGETHORPEAVE,FULLERTON.',
#  'telephone': '(714)879-3574',
#  'date': '12/30/2016FRI',
#  'time': '19:19',
#  'subtotal': '$55.96',
#  'tax': '$4.48',
#  'total': '$60.44',
#  'ignore': ' ',
#  'tips': '',
#  'line_items': [{'item_key': '',
#    'item_name': 'BIBIM.OCTOPUT1',
#    'item_value': '$13.99',
#    'item_quantity': '1'},
#   {'item_key': '',
#    'item_name': 'S-FOODP.CAKT1',
#    'item_value': '$14.99',
#    'item_quantity': '1'},
#   {'item_key': '',
#    'item_name': 'PORKDUMPLINT1',
#    'item_value': '$8.99',
#    'item_quantity': '1'},
#   {'item_key': '',
#    'item_name': 'LABEEFRIBT1',
#    'item_value': '￥17.99',
#    'item_quantity': '1'},
#   {'item_key': '4.00xITEMS',
#    'item_name': '',
#    'item_value': '',
#    'item_quantity': ''}]}

# %%
def _target_change(t: str):
    t = json.loads(json.loads(t))
    del t['tax']
    del t['subtotal']
    del t['ignore']
    del t['tips']
    for d in t['line_items']:
        del d['item_key']
    return json.dumps(t)

# %%
s = _target_change(ds['text'][0])

# %%
ds['text'].apply(_target_change)
# Out:
# 0      {"store_name": "CHOEUN KOREANRESTAURANT", "sto...
# 1      {"store_name": "ILIO'S Restaurant", "store_add...
# 2      {"store_name": "Aqwa aqua", "store_addr": "Lev...
# 3      {"store_name": "ONIONPUB&BREWERY", "store_addr...
# 4      {"store_name": "CAFFEVATICANO", "store_addr": ...
#                              ...
# 467    {"store_name": "KellyBeautySupply", "store_add...
# 468    {"store_name": "EDWARDSDRIVEIN", "store_addr":...
# 469    {"store_name": "SUE'SHALLMARK", "store_addr": ...
# 470    {"store_name": "GROCERY", "store_addr": "", "t...
# 471    {"store_name": "GREEN'SFEEDINC.", "store_addr"...
# Name: text, Length: 472, dtype: str

# %%
ds
# Out:
#                                                  image  \
# 0    {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 1    {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 2    {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 3    {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 4    {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# ..                                                 ...
# 467  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 468  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 469  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 470  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 471  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
#
#                                                   text
# 0    "{\"store_name\": \"CHOEUN KOREANRESTAURANT\",...
# 1    "{\"store_name\": \"ILIO'S Restaurant\", \"sto...
# 2    "{\"store_name\": \"Aqwa aqua\", \"store_addr\...
# 3    "{\"store_name\": \"ONIONPUB&BREWERY\", \"stor...
# 4    "{\"store_name\": \"CAFFEVATICANO\", \"store_a...
# ..                                                 ...
# 467  "{\"store_name\": \"KellyBeautySupply\", \"sto...
# 468  "{\"store_name\": \"EDWARDSDRIVEIN\", \"store_...
# 469  "{\"store_name\": \"SUE'SHALLMARK\", \"store_a...
# 470  "{\"store_name\": \"GROCERY\", \"store_addr\":...
# 471  "{\"store_name\": \"GREEN'SFEEDINC.\", \"store...
#
# [472 rows x 2 columns]
